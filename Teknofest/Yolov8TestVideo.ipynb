# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install ultralytics

# %%
ROOT_DIR = '/content/gdrive/MyDrive/UAVDataset'

# %%
import os

from ultralytics import YOLO
import cv2


VIDEOS_DIR = os.path.join(ROOT_DIR, 'videos')

video_path = os.path.join(VIDEOS_DIR, 'video2.mp4')
video_path_out = os.path.join(VIDEOS_DIR, 'video2res2.mp4')

cap = cv2.VideoCapture(video_path)
ret, frame = cap.read()
H, W, _ = frame.shape
out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*'MP4V'), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))

model_path = os.path.join(ROOT_DIR, 'results-802', 'runs', 'detect', 'train', 'weights', 'best.pt')

# Load a model
model = YOLO(model_path)  # load a custom model

threshold = 0.5

while ret:

    results = model(frame)[0]

    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        if score > threshold:
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
            cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)

    out.write(frame)
    ret, frame = cap.read()

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# Streaming output truncated to the last 5000 lines.
# 0: 384x640 1 uav, 236.1ms
# Speed: 2.6ms preprocess, 236.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 uav, 230.2ms
# Speed: 6.1ms preprocess, 230.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 uav, 252.6ms
# Speed: 6.9ms preprocess, 252.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 uavs, 236.7ms
# Speed: 5.4ms preprocess, 236.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 uavs, 235.5ms
# Speed: 4.1ms preprocess, 235.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 uav, 237.2ms
# Speed: 8.5ms preprocess, 237.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 uavs, 248.7ms
# Speed: 5.0ms preprocess, 248.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 uav, 228.5ms
# ...
